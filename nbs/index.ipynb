# %% [markdown]
# # fhvite
#
# > Vite plugin for FastHTML/MonsterUI that automates installation & building

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/AnswerDotAI/fhvite.git
# ```
#
#
# [repo]: https://github.com/AnswerDotAI/fhvite
# [docs]: https://AnswerDotAI.github.io/fhvite/

# %% [markdown]
# **Note:** \
# Make sure you have `npm` and `nodejs` installed in your path

# %% [markdown]
# I recommend using `nvm` to manage nodejs versioning. You can follow these cmd's extracted from the [official nodejs docs](https://nodejs.org/en/download)
#
# ```sh
# # Download and install nvm:
# curl -o- https://raw.githubusercontent.com/nvm-sh/nvm/v0.40.3/install.sh | bash
#
# # in lieu of restarting the shell
# \. "$HOME/.nvm/nvm.sh"
#
# # Download and install Node.js:
# nvm install 22
# ```

# %% [markdown]
# ## How to use

# %% [markdown]
# Import into an existing FastHTML application and add the following:

# %%
from fasthtml.common import *

# Add this import
from fhvite.core import add_vite

app = FastHTML()

# Add this line
add_vite(app)
# Out:
# > fastvite@0.0.0 build
# > vite build
#
# vite v7.0.4 building for production...
# transforming...
# ✓ 3 modules transformed.
# rendering chunks...
# computing gzip size...
# ../dist/.vite/manifest.json          0.19 kB │ gzip:  0.14 kB
# ../dist/assets/index-DwAzhI66.css  215.53 kB │ gzip: 25.35 kB
# ../dist/assets/index-DSGW5Iaw.js     0.71 kB │ gzip:  0.40 kB
# ✓ built in 103ms

# %% [markdown]
# All necessary setup files will be generated if not already present. After that, subsequent server starts will simply build the assets and inject them into the app header.

# %% [markdown]
# The plugin function also mounts a starlette `StaticFiles` route automatically, making the generated assets benefit from proper cacheing and static serving rules.
